# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

start_time = pd.datetime.now()

# %%
mydata = pd.read_csv('NY property data.csv')

# %%
mydata.shape
# Out:
# (1070994, 32)

# %%
numrecords = len(mydata)
print(numrecords)
# Out:
# 1070994

# %%
import pandas_profiling
profile = pandas_profiling.ProfileReport(mydata)
profile.to_file('DQR.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-419a7316cc68> in <module>
# ----> 1 import pandas_profiling
#       2 profile = pandas_profiling.ProfileReport(mydata)
#       3 profile.to_file('DQR.html')
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
mydata.dtypes
# Out:
# RECORD        int64
# BBLE         object
# B             int64
# BLOCK         int64
# LOT           int64
# EASEMENT     object
# OWNER        object
# BLDGCL       object
# TAXCLASS     object
# LTFRONT       int64
# LTDEPTH       int64
# EXT          object
# STORIES     float64
# FULLVAL     float64
# AVLAND      float64
# AVTOT       float64
# EXLAND      float64
# EXTOT       float64
# EXCD1       float64
# STADDR       object
# ZIP         float64
# EXMPTCL      object
# BLDFRONT      int64
# BLDDEPTH      int64
# AVLAND2     float64
# AVTOT2      float64
# EXLAND2     float64
# EXTOT2      float64
# EXCD2       float64
# PERIOD       object
# YEAR         object
# VALTYPE      object
# dtype: object

# %%
mydata.head(10).transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# ...

# %%
mydata.tail().transpose()
# Out:
#                      1070989             1070990             1070991  \
# RECORD               1070990             1070991             1070992
# BBLE              5080500083          5080500086          5080500089
# B                          5                   5                   5
# BLOCK                   8050                8050                8050
# LOT                       83                  86                  89
# EASEMENT                 NaN                 NaN                 NaN
# OWNER            TOBIN, GALE    SHERRI MILINAZZO        JOHN GERVASI
# BLDGCL                    A1                  A1                  A1
# TAXCLASS                   1                   1                   1
# LTFRONT                   60                  62                  53
# LTDEPTH                  120                 228                 273
# EXT                      NaN                 NaN                   G
# STORIES                  2.5                 2.5                   2
# ...

# %%
mydata.describe()
# Out:
#              RECORD             B         BLOCK           LOT       LTFRONT  \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   5.354975e+05  3.215427e+00  4.757239e+03  3.647221e+02  3.663530e+01
# std    3.091695e+05  1.201197e+00  3.676579e+03  8.532152e+02  7.403284e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.677492e+05  3.000000e+00  1.555000e+03  2.300000e+01  1.900000e+01
# 50%    5.354975e+05  3.000000e+00  4.047000e+03  4.900000e+01  2.500000e+01
# 75%    8.032458e+05  4.000000e+00  6.898000e+03  1.430000e+02  4.000000e+01
# max    1.070994e+06  5.000000e+00  1.635000e+04  9.978000e+03  9.999000e+03
#
#             LTDEPTH       STORIES       FULLVAL        AVLAND         AVTOT  \
# count  1.070994e+06  1.014730e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   8.886159e+01  5.006918e+00  8.742645e+05  8.506792e+04  2.272382e+05
# ...

# %%
mydata.count()
# Out:
# RECORD      1070994
# BBLE        1070994
# B           1070994
# BLOCK       1070994
# LOT         1070994
# EASEMENT       4636
# OWNER       1039251
# BLDGCL      1070994
# TAXCLASS    1070994
# LTFRONT     1070994
# LTDEPTH     1070994
# EXT          354305
# STORIES     1014730
# FULLVAL     1070994
# AVLAND      1070994
# AVTOT       1070994
# EXLAND      1070994
# EXTOT       1070994
# EXCD1        638488
# STADDR      1070318
# ZIP         1041104
# EXMPTCL       15579
# BLDFRONT    1070994
# BLDDEPTH    1070994
# AVLAND2      282726
# AVTOT2       282732
# EXLAND2       87449
# EXTOT2       130828
# EXCD2         92948
# PERIOD      1070994
# YEAR        1070994
# VALTYPE     1070994
# dtype: int64

# %%
mydata['RECORD'].unique()
# Out:
# array([      1,       2,       3, ..., 1070992, 1070993, 1070994])

# %%
len(mydata['RECORD'])
# Out:
# 1070994

# %%
plot = sns.countplot(x='EASEMENT', data = mydata, order = mydata['EASEMENT'].value_counts().index)

# %%
# mydata.set_index('RECORD', inplace = True)

# %%
len(mydata['BBLE'].unique())
# Out:
# 1070994

# %%
mydata['BBLE'].head()
# Out:
# 0    1000010101
# 1    1000010201
# 2    1000020001
# 3    1000020023
# 4    1000030001
# Name: BBLE, dtype: object

# %%
mydata['BBLE'].tail()
# Out:
# 1070989    5080500083
# 1070990    5080500086
# 1070991    5080500089
# 1070992    5080500092
# 1070993    5080500094
# Name: BBLE, dtype: object

# %%
len(mydata['B'].unique())
# Out:
# 5

# %%
mydata['B'].value_counts()
# Out:
# 4    358046
# 3    323243
# 1    146220
# 5    136200
# 2    107285
# Name: B, dtype: int64

# %%
mydata['B'].count() * 100 / numrecords
# Out:
# 100.0

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='B', data = mydata, order = mydata['B'].value_counts().index)
plt.savefig('hist.png')

# %%
mydata['BLOCK'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['BLOCK'].unique())
# Out:
# 13984

# %%
mydata['BLOCK'].value_counts()
# Out:
# 3944     3888
# 16       3786
# 3943     3424
# 3938     2794
# 1171     2535
# 3937     2275
# 1833     1774
# 2450     1651
# 1047     1480
# 7279     1302
# 5893     1295
# 8720     1281
# 936      1151
# 1115     1090
# 1320     1049
# 1140     1017
# 1011      991
# 943       946
# 1116      881
# 1515      869
# 3432      853
# 1537      842
# 1040      821
# 870       809
# 1536      796
# 1165      762
# 1048      753
# 5137      744
# 1373      736
# 1419      712
#          ...
# 10756       1
# 15879       1
# 8087        1
# 15864       1
# 15865       1
# 10118       1
# 9106        1
# 13816       1
# 15866       1
# 15867       1
# 9117        1
# 16286       1
# 15876       1
# 15875       1
# 15873       1
# 15887       1
# 15886       1
# 10127       1
# 15885       1
# 15884       1
# 9629        1
# 15883       1
# 15882       1
# 15881       1
# 10593       1
# 15880       1
# 15895       1
# 15892       1
# 10119       1
# 9067        1
# ...

# %%
mydata['BLOCK'].min()
# Out:
# 1

# %%
B1 = mydata[mydata['B']==1]

# %%
B1.head(10).transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# B                             1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# ...

# %%
B1.tail(10).transpose()
# Out:
#                        146210                 146211               146212  \
# RECORD                 146211                 146212               146213
# BBLE               1022500078             1022500080           1022500084
# B                           1                      1                    1
# BLOCK                    2250                   2250                 2250
# LOT                        78                     80                   84
# EASEMENT                  NaN                    NaN                  NaN
# OWNER     256 SEAMAN AVE. LLC  254 SEAMAN AVENUE ALD  ROBERT E HILL, TNC.
# BLDGCL                     C1                     D1                   D4
# TAXCLASS                    2                      2                    2
# LTFRONT                    50                    100                   50
# LTDEPTH                   140                    140                  150
# EXT                       NaN                    NaN                  NaN
# ...

# %%
B1['BLOCK'].value_counts()
# Out:
# 16      3538
# 1171    2295
# 1833    1661
# 1047    1321
# 936     1124
#         ...
# 120        1
# 673        1
# 1605       1
# 403        1
# 932        1
# Name: BLOCK, Length: 1962, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='BLOCK', data = B1, order = B1['BLOCK'].value_counts().iloc[:10].index)
plt.savefig('BLOCK_B1.png')

# %%
B2 = mydata[mydata['B']==2]

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='BLOCK', data = B2, order = B2['BLOCK'].value_counts().iloc[:10].index)
plt.savefig('BLOCK_B2.png')

# %%
B3 = mydata[mydata['B']==3]

# %% [markdown]
# plt.rcParams["figure.figsize"] = [15,8]
# sns.set(font_scale=2)
# plot = sns.countplot(x='BLOCK', data = B3, order = B3['BLOCK'].value_counts().iloc[:10].index)
# plt.savefig('BLOCK_B3.png')

# %%
B4 = mydata[mydata['B']==4]

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='BLOCK', data = B4, order = B4['BLOCK'].value_counts().iloc[:10].index)
plt.savefig('BLOCK_B4.png')

# %%
B5 = mydata[mydata['B']==5]

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='BLOCK', data = B5, order = B5['BLOCK'].value_counts().iloc[:10].index)
plt.savefig('BLOCK_B5.png')

# %%
mydata['LOT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['LOT'].unique())
# Out:
# 6366

# %%
mydata['LOT'].value_counts()
# Out:
# 1       24367
# 20      12294
# 15      12171
# 12      12143
# 14      12074
# 16      12042
# 17      11982
# 18      11979
# 25      11949
# 21      11840
# 23      11705
# 22      11665
# 6       11646
# 19      11640
# 30      11596
# 24      11591
# 26      11584
# 28      11369
# 29      11357
# 7       11340
# 27      11339
# 13      11315
# 9       11114
# 10      11083
# 11      11017
# 8       10895
# 32      10815
# 33      10754
# 31      10720
# 35      10719
#         ...
# 6046        1
# 7289        1
# 7120        1
# 4956        1
# 7290        1
# 5457        1
# 7291        1
# 8144        1
# 6097        1
# 7284        1
# 5462        1
# 7285        1
# 5544        1
# 6026        1
# 7283        1
# 7127        1
# 7287        1
# 9112        1
# 6102        1
# 8151        1
# 5463        1
# 7280        1
# 7281        1
# 7126        1
# 7282        1
# 5547        1
# 8075        1
# 6883        1
# 5460        1
# 9108        1
# ...

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='LOT', data = mydata, order = mydata['LOT'].value_counts().iloc[:10].index)

# %%
mydata['LOT'].min()
# Out:
# 1

# %%
mydata['LOT'].max()
# Out:
# 9978

# %%
mydata['LOT'].mean()
# Out:
# 364.7221170239983

# %%
mydata['LOT'].std()
# Out:
# 853.2152428518039

# %%
mydata['EASEMENT'].count() * 100 / numrecords
# Out:
# 0.4328689049611856

# %%
len(mydata['EASEMENT'].unique())
# Out:
# 13

# %%
mydata['EASEMENT'].value_counts()
# Out:
# E    4148
# F     296
# G     102
# H      33
# N      19
# I      16
# J       8
# K       5
# P       3
# L       3
# M       2
# U       1
# Name: EASEMENT, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='EASEMENT', data = mydata, order = mydata['EASEMENT'].value_counts().index)
plot.set_yscale('log')
plt.savefig('EASEMENT.png')

# %%
mydata['OWNER'].count() * 100 / numrecords
# Out:
# 97.03611784939972

# %%
mydata['OWNER'].count()
# Out:
# 1039251

# %%
len(mydata['OWNER'].unique())
# Out:
# 863349

# %%
mydata['OWNER'].value_counts()
# Out:
# PARKCHESTER PRESERVAT    6021
# PARKS AND RECREATION     4255
# DCAS                     2169
# HOUSING PRESERVATION     1904
# CITY OF NEW YORK         1450
# DEPT OF ENVIRONMENTAL    1166
# BOARD OF EDUCATION       1015
# NEW YORK CITY HOUSING    1014
# CNY/NYCTA                 975
# NYC HOUSING PARTNERSH     747
# YORKVILLE TOWERS ASSO     558
# DEPARTMENT OF BUSINES     527
# DEPT OF TRANSPORTATIO     503
# MTA/LIRR                  467
# PARCKHESTER PRESERVAT     439
# MH RESIDENTIAL 1, LLC     411
# 434 M LLC                 393
# LINCOLN PLAZA ASSOCIA     366
# DEUTSCHE BANK NATIONA     336
# 561 11TH AVENUE TMG L     323
# OCEAN SHELL LLC           314
# CPW TOWERS                314
# DORCHESTER ASSOCIATES     313
# PM PARTNERS               301
# 99 JOHN ST.,LLC           296
# NEW YORK CITY TRANSIT     278
# FIRE DEPARTMENT           255
# TRUSTEES OF COLUMBIA      239
# DEPT OF GENERAL SERVI     224
# BRIGHTWATER TOWERS        222
#                          ...
# ...

# %%
plt.rcParams["figure.figsize"] = [10, 3]
mydata['OWNER'].value_counts().head(25).plot(kind='bar')
plt.savefig('OWNER.png')

# %%
mydata['BLDGCL'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['BLDGCL'].unique())
# Out:
# 200

# %%
mydata['BLDGCL'].value_counts()
# Out:
# R4    139879
# A1    123369
# A5     96984
# B1     84208
# B2     77598
# C0     73111
# B3     59240
# A2     51130
# A9     26177
# B9     26133
# V0     24049
# R5     23957
# R3     21667
# C3     16343
# C1     15070
# S2     14507
# C2     13633
# R2     10558
# R1      8015
# K1      7596
# C7      7546
# V1      7223
# A0      6889
# A3      6332
# S1      6195
# R0      5696
# G7      5603
# D1      5101
# S9      4125
# K9      4080
#        ...
# Y4        28
# H1        28
# Y8        28
# F8        26
# U0        25
# Y7        25
# J5        20
# C8        18
# J8        18
# Q5        17
# V4        17
# U5        17
# N1        16
# Y3        16
# T1        15
# V6        14
# P4        14
# P1        13
# J1        12
# N3        11
# J3         8
# J7         8
# N4         7
# J2         7
# Z5         6
# I3         4
# I2         4
# H7         3
# Y5         1
# E6         1
# Name: BLDGCL, Length: 200, dtype: int64

# %%
mydata[mydata['BLDGCL'] == 0]
# Out:
# Empty DataFrame
# Columns: [RECORD, BBLE, B, BLOCK, LOT, EASEMENT, OWNER, BLDGCL, TAXCLASS, LTFRONT, LTDEPTH, EXT, STORIES, FULLVAL, AVLAND, AVTOT, EXLAND, EXTOT, EXCD1, STADDR, ZIP, EXMPTCL, BLDFRONT, BLDDEPTH, AVLAND2, AVTOT2, EXLAND2, EXTOT2, EXCD2, PERIOD, YEAR, VALTYPE]
# Index: []
#
# [0 rows x 32 columns]

# %%
plt.rcParams["figure.figsize"] = [15,8]
#plt.rcParams["axes.labelsize"] = 1
sns.set(font_scale=1.5)
plot = sns.countplot(x='BLDGCL', data = mydata, order = mydata['BLDGCL'].value_counts().iloc[:80].index)
#plot.set_yscale('log')
#plt.savefig('BLDGCL.png')
plot.set_xticklabels(plot.get_xticklabels(), rotation=65, fontsize = 10)
plt.savefig('BLDGCL.png')

# %%
mydata['TAXCLASS'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['TAXCLASS'].unique())
# Out:
# 11

# %%
mydata['TAXCLASS'].value_counts()
# Out:
# 1     660721
# 2     188612
# 4     104310
# 2A     40574
# 1B     24738
# 1A     21667
# 2B     13964
# 2C     10795
# 3       4638
# 1C       946
# 1D        29
# Name: TAXCLASS, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='TAXCLASS', data = mydata, order = mydata['TAXCLASS'].value_counts().index)
plot.set_yscale('log')
plt.savefig('TAXCLASS.png')

# %%
mydata['LTFRONT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.distplot(mydata['LTFRONT'])

# %%
sns.boxplot(x='LTFRONT', data=mydata)

# %%
sns.distplot(mydata['LTFRONT'])

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['LTFRONT'] <= xhigh]
sns.distplot(temp['LTFRONT'],bins=100, kde=True)
plt.savefig('LTFRONT.png')

# %%
max(mydata['LTFRONT'])
# Out:
# 9999

# %%
len(mydata[mydata['LTFRONT']==0])
# Out:
# 169108

# %%
len(mydata[mydata['LTFRONT']==1])
# Out:
# 839

# %%
len(mydata[mydata["LTFRONT"]==2])
# Out:
# 762

# %%
mydata['LTFRONT'].value_counts()
# Out:
# 0       169108
# 20      135178
# 25      117306
# 40       85389
# 18       40668
# 50       39897
# 30       36340
# 24       25710
# 19       25381
# 22       23420
# 26       19721
# 21       19376
# 16       18636
# 23       16937
# 60       14972
# 100      13952
# 28       13230
# 27       12648
# 17       10522
# 29        9366
# 37        8158
# 33        8126
# 35        7868
# 32        7619
# 31        7388
# 45        7032
# 75        6862
# 41        6240
# 42        5965
# 15        5283
#          ...
# 782          1
# 5400         1
# 2290         1
# 781          1
# 1269         1
# 1270         1
# 2294         1
# 5370         1
# 1276         1
# 2300         1
# 1282         1
# 1283         1
# 1802         1
# 2309         1
# 1284         1
# 1285         1
# 5380         1
# 1287         1
# 1290         1
# 776          1
# 1295         1
# 1297         1
# 775          1
# 1299         1
# 1300         1
# 1301         1
# 1302         1
# ...

# %%
mydata['LTDEPTH'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='LTDEPTH', data=mydata)

# %%
sns.distplot(mydata['LTDEPTH'],kde=False)

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['LTDEPTH'] <= xhigh]
sns.distplot(temp['LTDEPTH'],bins=100, kde=True)
plt.savefig('LTDEPTH.png')

# %%
max(mydata['LTDEPTH'])
# Out:
# 9999

# %%
np.mean(mydata['LTDEPTH'])
# Out:
# 88.86159399585806

# %%
len(mydata[mydata['LTDEPTH']==0])
# Out:
# 170128

# %%
len(mydata[mydata['LTDEPTH']==1])
# Out:
# 127

# %%
len(mydata[mydata["LTDEPTH"]==2])
# Out:
# 84

# %%
mydata['LTDEPTH'].value_counts()
# Out:
# 100     464541
# 0       170128
# 95       31612
# 90       20294
# 80       16671
# 99       11390
# 97       10227
# 75       10161
# 102       9607
# 96        9329
# 110       8943
# 98        8757
# 105       8522
# 101       7697
# 120       7683
# 85        7328
# 125       7324
# 103       6995
# 92        6734
# 200       6692
# 94        5971
# 93        4964
# 107       4810
# 109       4528
# 60        4522
# 50        4505
# 87        4449
# 104       4414
# 150       4393
# 114       4246
#          ...
# 1251         1
# 1825         1
# 1231         1
# 2866         1
# 838          1
# 819          1
# 1860         1
# 4934         1
# 2231         1
# 2885         1
# 8000         1
# 835          1
# 1209         1
# 832          1
# 5948         1
# 1477         1
# 1853         1
# 1215         1
# 3900         1
# 1476         1
# 1218         1
# 827          1
# 2875         1
# 1472         1
# 1222         1
# 1471         1
# 1224         1
# ...

# %%
mydata['EXT'].value_counts()
# Out:
# G     266970
# E      49442
# EG     37893
# Name: EXT, dtype: int64

# %%
mydata['EXT'].count() * 100 / numrecords
# Out:
# 33.081884679092504

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='EXT', data = mydata, order = mydata['EXT'].value_counts().index)
#plot.set_yscale('log')
plt.savefig('EXT.png')

# %%
mydata['STORIES'].count() * 100 / numrecords
# Out:
# 94.74656253909919

# %%
sum(pd.isnull(mydata['STORIES']))
# Out:
# 56264

# %%
sns.boxplot(x='STORIES', data=mydata)
plt.savefig("boxplot.png")

# %%
len(mydata[mydata['STORIES'] == 0])
# Out:
# 0

# %%
sns.boxplot(x='STORIES', data=mydata)

# %%
xhigh = 50
temp = mydata[mydata['STORIES'] > 0]
temp.count()
plt.xlim(0,xhigh)
temp = temp[temp['STORIES'] <= xhigh]
sns.distplot(temp['STORIES'],bins=51, kde=True)
plt.savefig('STORIES.png')

# %%
len(mydata[mydata['STORIES'] == 1])
# Out:
# 96706

# %%
mydata['STORIES'].value_counts()
# Out:
# 2.0      415092
# 3.0      130127
# 1.0       96706
# 2.5       82292
# 4.0       38342
# 6.0       30936
# 5.0       25971
# 1.5       24770
# 2.7       13595
# 12.0      12198
# 8.0       11953
# 7.0       11899
# 1.6        8954
# 9.0        7343
# 13.0       7330
# 16.0       5428
# 1.7        5239
# 21.0       4885
# 19.0       4866
# 11.0       4459
# 15.0       4270
# 10.0       3758
# 17.0       3457
# 14.0       3368
# 20.0       3142
# 32.0       3127
# 30.0       2905
# 42.0       2875
# 31.0       2583
# 27.0       2333
#           ...
# 6.7          12
# 59.0         12
# 3.6          11
# 47.0         10
# 4.7          10
# 1.9          10
# 74.0          6
# 3.3           5
# 100.0         5
# 9.5           4
# 62.0          3
# 2.8           3
# 1.1           3
# 1.3           3
# 8.5           3
# 68.0          2
# 2.9           2
# 5.7           2
# 1.4           2
# 63.0          2
# 2.4           2
# 119.0         1
# 82.0          1
# 4.2           1
# ...

# %%
mydata['FULLVAL'].count() * 100 / numrecords
# Out:
# 100.0

# %%
mydata['FULLVAL'].value_counts()
# Out:
# 0.0           13007
# 502000.0       2796
# 366000.0       2290
# 397000.0       2231
# 472000.0       2223
#               ...
# 1163460.0         1
# 367292.0          1
# 367290.0          1
# 18240000.0        1
# 422445.0          1
# Name: FULLVAL, Length: 109324, dtype: int64

# %%
sns.boxplot(x='FULLVAL', data=mydata)
plt.savefig("boxplot.png")

# %%
sns.distplot(mydata['FULLVAL'],kde=False)
plt.savefig('dist bad.png')

# %%
max(mydata['FULLVAL'])
# Out:
# 6150000000.0

# %%
min(mydata['FULLVAL'])
# Out:
# 0.0

# %%
np.std(mydata['FULLVAL'])
# Out:
# 11582425.583347425

# %%
len(mydata[mydata['FULLVAL']==0])
# Out:
# 13007

# %%
len(mydata[mydata['FULLVAL']==1])
# Out:
# 0

# %%
len(mydata[mydata["FULLVAL"]==2])
# Out:
# 0

# %%
temp = mydata[mydata['FULLVAL'] >= 0]
ax = sns.distplot(temp['FULLVAL'],bins=100, kde=False)
ax.set_yscale('log')
plt.savefig('log.png')

# %%
temp = mydata[mydata['FULLVAL'] >= 0]
ax = sns.distplot(temp['FULLVAL'],bins=100, kde=False)
ax.set_yscale('log')
ax.set_xscale('log')
plt.savefig('loglog.png')

# %%
xhigh = 2000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=100, kde=False)
plt.savefig('dist good.png')

# %%
xhigh = 2000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=10, kde=False)
plt.savefig('dist good.png')

# %%
xhigh = 2000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=1000, kde=False)
plt.savefig('dist good.png')

# %%
xhigh = 1000000
plt.xlim(0,xhigh)
temp = mydata[mydata['FULLVAL'] <= xhigh]
sns.distplot(temp['FULLVAL'],bins=100, kde=True)

# %%
xhigh = 100000
plt.xlim(0,xhigh)
temp = mydata[(mydata['FULLVAL'] <= xhigh) & (mydata['FULLVAL']) > 0]
sns.distplot(temp['FULLVAL'],bins=100, kde=False)

# %%
len(mydata[mydata['FULLVAL'] == 0])
# Out:
# 13007

# %%
mydata['AVLAND'].value_counts()
# Out:
# 0.0         13009
# 45000.0      1229
# 90000.0       999
# 3045.0        873
# 22500.0       847
#             ...
# 129219.0        1
# 45566.0         1
# 45565.0         1
# 45560.0         1
# 131065.0        1
# Name: AVLAND, Length: 70921, dtype: int64

# %%
temp = mydata[mydata['AVLAND'] != 0]

# %%
temp['AVLAND'].value_counts()
# Out:
# 45000.0     1229
# 90000.0      999
# 3045.0       873
# 22500.0      847
# 18000.0      802
#             ...
# 336348.0       1
# 58141.0        1
# 58132.0        1
# 58127.0        1
# 131065.0       1
# Name: AVLAND, Length: 70920, dtype: int64

# %%
mydata['AVLAND'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='AVLAND', data=mydata)

# %%
sns.distplot(mydata['AVLAND'],kde=False)

# %%
len(mydata[mydata['AVLAND']==0])
# Out:
# 13009

# %%
len(mydata[mydata['AVLAND']==1])
# Out:
# 3

# %%
len(mydata[mydata["AVLAND"]==2])
# Out:
# 13

# %%
xhigh = 50000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVLAND'] <= xhigh]
sns.distplot(temp['AVLAND'],bins=100, kde=True)
plt.savefig('AVLAND.png')

# %%
mydata['AVTOT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='AVTOT', data=mydata)

# %%
xhigh = 100000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVTOT'] <= xhigh]
sns.distplot(temp['AVTOT'],bins=100, kde=True)
plt.savefig('AVTOT.png')

# %%
len(mydata[mydata['AVTOT']==0])
# Out:
# 13007

# %%
len(mydata[mydata['AVTOT']==1])
# Out:
# 3

# %%
len(mydata[mydata["AVTOT"]==2])
# Out:
# 2

# %%
mydata['EXLAND'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='EXLAND', data=mydata)

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
xhigh = 20000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXLAND'] <= xhigh]
sns.distplot(temp['EXLAND'],bins=100, kde=False)
plt.savefig('EXLAND.png')

# %%
len(mydata[mydata['EXLAND']==0])
# Out:
# 491699

# %%
len(mydata[mydata['EXLAND']==1])
# Out:
# 8

# %%
len(mydata[mydata["EXLAND"]==2])
# Out:
# 15

# %%
mydata['EXTOT'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='EXTOT', data=mydata)

# %%
xhigh = 10000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXTOT'] <= xhigh]
sns.distplot(temp['EXTOT'],bins=100, kde=False)
plt.savefig('EXTOT.png')

# %%
np.mean(mydata['EXTOT'])
# Out:
# 91186.98168243706

# %%
min(mydata['EXTOT'])
# Out:
# 0.0

# %%
max(mydata['EXTOT'])
# Out:
# 4668308947.0

# %%
np.std(mydata['EXTOT'])
# Out:
# 6508399.780298874

# %%
len(mydata[mydata['EXTOT']==0])
# Out:
# 432572

# %%
len(mydata[mydata['EXTOT']==1])
# Out:
# 10

# %%
len(mydata[mydata["EXTOT"]==2])
# Out:
# 2

# %%
mydata['EXCD1'].count() * 100 / numrecords
# Out:
# 59.616393742635346

# %%
sns.boxplot(x='EXCD1', data=mydata)

# %%
xhigh = 10000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXCD1'] <= xhigh]
sns.distplot(temp['EXCD1'],bins=100, kde=False)
plt.savefig('EXCD1.png')

# %%
len(mydata[mydata['EXCD1']==0])
# Out:
# 0

# %%
len(mydata[mydata['EXCD1']==1])
# Out:
# 0

# %%
len(mydata[mydata["EXCD1"]==2])
# Out:
# 0

# %%
mydata['STADDR'].count() * 100 / numrecords
# Out:
# 99.93688106562689

# %%
len(mydata['STADDR'].unique())
# Out:
# 839281

# %%
sum(mydata['STADDR'].value_counts())
# Out:
# 1070318

# %%
mydata['STADDR'].value_counts()
# Out:
# 501 SURF AVENUE            902
# 330 EAST 38 STREET         817
# 322 WEST 57 STREET         720
# 155 WEST 68 STREET         671
# 20 WEST 64 STREET          657
# 1 IRVING PLACE             650
# 220 RIVERSIDE BOULEVARD    628
# 360 FURMAN STREET          599
# 200 EAST 66 STREET         585
# 30 WEST 63 STREET          562
# 2 BAY CLUB DRIVE           556
# 350 WEST 42 STREET         556
# 200 RECTOR PLACE           549
# 301 EAST 79 STREET         538
# 350 WEST 50 STREET         498
# 630 1 AVENUE               488
# 635 WEST 42 STREET         483
# 88 GREENWICH STREET        453
# 150 WEST 51 STREET         447
# 99 JOHN STREET             445
# 25 CENTRAL PARK WEST       441
# 138-35 ELDER AVENUE        437
# 1623 3 AVENUE              434
# 1 BAY CLUB DRIVE           427
# 5 EAST 22 STREET           426
# 310 WEST 52 STREET         425
# 106 CENTRAL PARK SOUTH     420
# 400 CENTRAL PARK WEST      415
# 382 CENTRAL PARK WEST      415
# 25-40 SHORE BOULEVARD      415
# ...

# %%
plt.rcParams["figure.figsize"] = [10, 3]
mydata['STADDR'].value_counts().head(25).plot(kind='bar')
#plt.savefig('STADDR.png')

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='STADDR', data = mydata, order = mydata['STADDR'].value_counts().iloc[:25].index)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90, fontsize = 15)
plt.savefig('STADDR.png')

# %%
mydata['ZIP'].count() * 100 / numrecords
# Out:
# 97.20913469169761

# %%
len(mydata['ZIP'].unique())
# Out:
# 197

# %%
sum(mydata['ZIP'].value_counts())
# Out:
# 1041104

# %%
mydata['ZIP'].value_counts()
# Out:
# 10314.0    24606
# 11234.0    20001
# 10312.0    18127
# 10462.0    16905
# 10306.0    16578
# 11236.0    15678
# 11385.0    14921
# 11229.0    12793
# 11211.0    12710
# 11207.0    12293
# 11215.0    11834
# 11235.0    11312
# 11203.0    11241
# 11208.0    11139
# 11204.0    11061
# 10469.0    11030
# 11214.0    10886
# 11223.0    10741
# 10305.0    10625
# 11434.0    10505
# 11355.0    10492
# 11219.0    10300
# 11357.0     9851
# 11413.0     9784
# 11373.0     9779
# 11220.0     9686
# 10023.0     9518
# 10309.0     9416
# 10016.0     9362
# 10019.0     9355
#            ...
# 10004.0      775
# 10006.0      721
# 10475.0      687
# 10034.0      650
# 10039.0      596
# 10044.0      588
# 10040.0      546
# 10037.0      526
# 11040.0      450
# 11239.0      195
# 11109.0      194
# 11243.0      185
# 10020.0      120
# 10803.0       46
# 10282.0       22
# 11430.0       14
# 11697.0       10
# 11227.0        5
# 33803.0        3
# 10281.0        3
# 11696.0        2
# ...

# %%
mydata['EXMPTCL'].count() * 100 / numrecords
# Out:
# 1.4546299979271593

# %%
len(mydata['EXMPTCL'].unique())
# Out:
# 15

# %%
mydata['EXMPTCL'].value_counts()
# Out:
# X1    6912
# X5    5208
# X7     820
# X2     770
# X6     764
# X4     441
# X8     292
# X3     259
# X9     108
# VI       1
# 5        1
# A9       1
# KI       1
# R4       1
# Name: EXMPTCL, dtype: int64

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
plot = sns.countplot(x='EXMPTCL', data = mydata, order = mydata['EXMPTCL'].value_counts().index)
plot.set_yscale('log')
#plot.set_xticklabels(plot.get_xticklabels(), rotation=90, fontsize = 15)
plt.savefig('EXMPTCL.png')

# %%
sns.boxplot(x='BLDFRONT', data=mydata)

# %%
xhigh = 200
plt.xlim(0,xhigh)
temp = mydata[mydata['BLDFRONT'] <= xhigh]
sns.distplot(temp['BLDFRONT'],bins=100, kde=False)
plt.savefig('BLDFRONT.png')

# %%
len(mydata[mydata['BLDFRONT']==0])
# Out:
# 228815

# %%
len(mydata[mydata['BLDFRONT']==1])
# Out:
# 77

# %%
len(mydata[mydata["BLDFRONT"]==2])
# Out:
# 21

# %%
mydata['BLDDEPTH'].count() * 100 / numrecords
# Out:
# 100.0

# %%
sns.boxplot(x='BLDDEPTH', data=mydata)

# %%
xhigh = 300
plt.xlim(0,xhigh)
temp = mydata[mydata['BLDDEPTH'] <= xhigh]
sns.distplot(temp['BLDDEPTH'],bins=100, kde=False)
plt.savefig('BLDDEPTH.png')

# %%
len(mydata[mydata['BLDDEPTH']==0])
# Out:
# 228853

# %%
len(mydata[mydata['BLDDEPTH']==1])
# Out:
# 59

# %%
len(mydata[mydata["BLDDEPTH"]==2])
# Out:
# 10

# %%
mydata['AVLAND2'].count() * 100 / numrecords
# Out:
# 26.398467218303743

# %%
mydata['AVLAND2'].count() * 100/ numrecords
# Out:
# 26.398467218303743

# %%
sns.boxplot(x='AVLAND2', data=mydata)

# %%
xhigh = 300000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVLAND2'] <= xhigh]
sns.distplot(temp['AVLAND2'],bins=100, kde=False)
plt.savefig('AVLAND2.png')

# %%
mydata['AVTOT2'].count() * 100 / numrecords
# Out:
# 26.399027445531907

# %%
sns.boxplot(x='AVTOT2', data=mydata)

# %%
plt.rcParams["figure.figsize"] = [15,8]
sns.set(font_scale=2)
xhigh = 1000000
plt.xlim(0,xhigh)
temp = mydata[mydata['AVTOT2'] <= xhigh]
sns.distplot(temp['AVTOT2'],bins=100, kde=False)
plt.savefig('AVTOT2.png')

# %%
mydata['EXLAND2'].count() * 100 / numrecords
# Out:
# 8.165218479281863

# %%
sns.boxplot(x='EXLAND2', data =mydata)

# %%
xhigh = 50000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXLAND2'] <= xhigh]
sns.distplot(temp['EXLAND2'],bins=100, kde=False)
plt.savefig('EXLAND2.png')

# %%
mydata['EXTOT2'].count() * 100 / numrecords
# Out:
# 12.215567967701032

# %%
sns.boxplot(x='EXTOT2', data=mydata)

# %%
xhigh = 300000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXTOT2'] <= xhigh]
sns.distplot(temp['EXTOT2'],bins=100, kde=False)
plt.savefig('EXTOT2.png')

# %%
mydata['EXCD2'].count() * 100 / numrecords
# Out:
# 8.678666733893934

# %%
sns.boxplot(x='EXCD2', data=mydata)

# %%
xhigh = 10000
plt.xlim(0,xhigh)
temp = mydata[mydata['EXCD2'] <= xhigh]
sns.distplot(temp['EXCD2'],bins=100, kde=False)
#plt.savefig('EXCD2.png')

# %%
mydata['PERIOD'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['PERIOD'].unique())
# Out:
# 1

# %%
mydata['PERIOD'].value_counts()
# Out:
# FINAL    1070994
# Name: PERIOD, dtype: int64

# %%
mydata['YEAR'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['YEAR'].unique())
# Out:
# 1

# %%
mydata['YEAR'].value_counts()
# Out:
# 2010/11    1070994
# Name: YEAR, dtype: int64

# %%
mydata['VALTYPE'].count() * 100 / numrecords
# Out:
# 100.0

# %%
len(mydata['VALTYPE'].unique())
# Out:
# 1

# %%
mydata['VALTYPE'].value_counts()
# Out:
# AC-TR    1070994
# Name: VALTYPE, dtype: int64

# %%
len(mydata[mydata['LTFRONT'] == 0])
# Out:
# 169108

# %%
len(mydata[mydata['LTDEPTH'] == 0])
# Out:
# 170128

# %%
len(mydata[(mydata['LTFRONT'] == 0) & (mydata['LTFRONT'] == 0)])
# Out:
# 169108

# %%
temp = mydata[(mydata['LTFRONT'] == 0) & (mydata['LTFRONT'] == 0)]

# %%
temp['BLDFRONT'].value_counts()
# Out:
# 0      150872
# 20        835
# 100       821
# 200       696
# 25        655
# 18        620
# 160       585
# 116       561
# 24        560
# 175       453
# 190       444
# 128       444
# 22        439
# 151       437
# 97        435
# 115       415
# 261       400
# 132       386
# 201       372
# 134       358
# 21        354
# 75        339
# 23        305
# 78        286
# 110       272
# 70        271
# 19        265
# 146       253
# 202       230
# 50        226
#         ...
# 264         2
# 13          2
# 206         2
# 180         2
# 182         2
# 214         2
# 532         2
# 220         2
# 870         1
# 982         1
# 158         1
# 81          1
# 179         1
# 900         1
# 133         1
# 243         1
# 6           1
# 111         1
# 48          1
# 421         1
# 199         1
# 265         1
# 94          1
# 222         1
# 195         1
# 140         1
# 155         1
# 95          1
# 106         1
# 780         1
# ...

# %%
temp['BLDDEPTH'].value_counts()
# Out:
# 0       150858
# 100       1262
# 97         733
# 596        584
# 106        563
# 24         538
# 125        491
# 146        453
# 172        445
# 179        413
# 149        412
# 185        400
# 48         385
# 60         381
# 99         361
# 115        358
# 298        347
# 65         333
# 64         320
# 221        315
# 98         282
# 50         277
# 135        274
# 102        269
# 198        251
# 43         251
# 42         234
# 327        229
# 40         212
# 70         206
#          ...
# 390          1
# 21           1
# 530          1
# 525          1
# 126          1
# 507          1
# 147          1
# 109          1
# 375          1
# 405          1
# 208          1
# 320          1
# 3390         1
# 1980         1
# 439          1
# 182          1
# 225          1
# 171          1
# 228          1
# 103          1
# 492          1
# 493          1
# 292          1
# 622          1
# 544          1
# 160          1
# 413          1
# ...

# %%
mydata['EASEMENT'].value_counts().head(20).plot(kind='bar',logy=True)

# %%
print('duration: ', pd.datetime.now() - start_time)
# Out:
# duration:  0:01:59.375938
